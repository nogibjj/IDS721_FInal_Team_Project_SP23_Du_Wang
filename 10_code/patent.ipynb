# %% [markdown]
# ## Patent

# %%
import numpy as np
import pandas as pd
# patent = pd.read_table('patent.txt', sep='~')
# patent.head()
# patent.to_csv('patent.csv', index=False)

# %%
patent_2019_2020 = pd.read_excel('2019.xlsx')
patent_2019_2020.head()
# Out:
#   INGREDIENT_STRING             DOSAGE_FORM        ROUTE TRADE_NAME APPL_TYPE  \
# 0      RIVASTIGMINE  FILM, EXTENDED RELEASE  TRANSDERMAL     EXELON         N
# 1      RIVASTIGMINE  FILM, EXTENDED RELEASE  TRANSDERMAL     EXELON         N
# 2      RIVASTIGMINE  FILM, EXTENDED RELEASE  TRANSDERMAL     EXELON         N
# 3      RIVASTIGMINE  FILM, EXTENDED RELEASE  TRANSDERMAL     EXELON         N
# 4      RIVASTIGMINE  FILM, EXTENDED RELEASE  TRANSDERMAL     EXELON         N
#
#    APPL_NO  PRODUCT_NO PATENT_NO EXPIRE_DATE PE_EXTENSION_FLAG  \
# 0    22083           1   6316023  2019-01-08                 N
# 1    22083           1   6335031  2019-01-08                 N
# 2    22083           2   6316023  2019-01-08                 N
# 3    22083           2   6335031  2019-01-08                 N
# 4    22083           5   6316023  2019-01-08                 N
#
#   PE_EXTENSION_DATE DRUG_SUBSTANCE_FLAG DRUG_PRODUCT_FLAG USE_CODE  \
# ...

# %%
df = pd.read_csv('drug_data.csv')
df.head()
# Out:
#                        Brnd_Name             Gnrc_Name  Tot_Mftr  \
# 0       1ST TIER UNIFINE PENTIPS  Pen Needle, Diabetic         1
# 1       1ST TIER UNIFINE PENTIPS  Pen Needle, Diabetic         1
# 2  1ST TIER UNIFINE PENTIPS PLUS  Pen Needle, Diabetic         1
# 3  1ST TIER UNIFINE PENTIPS PLUS  Pen Needle, Diabetic         1
# 4                       ABACAVIR      Abacavir Sulfate         7
#
#          Mftr_Name  Tot_Spndng_2017  Tot_Dsg_Unts_2017  Tot_Clms_2017  \
# 0          Overall        217938.04          1014318.0         8595.0
# 1  Owen Mumford Us        217938.04          1014318.0         8595.0
# 2          Overall        402124.68          1850703.0        15403.0
# 3  Owen Mumford Us        402124.68          1850703.0        15403.0
# 4          Overall      13386250.08          3189707.0        48283.0
#
#    Tot_Benes_2017  Avg_Spnd_Per_Dsg_Unt_Wghtd_2017  Avg_Spnd_Per_Clm_2017  \
# 0          3025.0                         0.216105              25.356375
# ...

# %%
unique_name = patent_2019_2020.INGREDIENT_STRING.unique()
len(unique_name)
df1 = df.copy()
for i in df["Brnd_Name"]:
    if i not in unique_name:
        df1.drop(df1[df1["Brnd_Name"] == i].index, inplace=True)
df1
# Out:
#                   Brnd_Name             Gnrc_Name  Tot_Mftr        Mftr_Name  \
# 667             AMOXICILLIN           Amoxicillin        10          Overall
# 668             AMOXICILLIN           Amoxicillin         1  West-Ward/Hikma
# 669             AMOXICILLIN           Amoxicillin         1         Teva USA
# 670             AMOXICILLIN           Amoxicillin         1           Sandoz
# 671             AMOXICILLIN           Amoxicillin         1     Rising Pharm
# ...                     ...                   ...       ...              ...
# 13048  VARENICLINE TARTRATE  Varenicline Tartrate         2          Overall
# 13049  VARENICLINE TARTRATE  Varenicline Tartrate         1       Par Pharm.
# 13050  VARENICLINE TARTRATE  Varenicline Tartrate         1      Apotex Corp
# 13207   VINCRISTINE SULFATE   Vincristine Sulfate         1          Overall
# 13208   VINCRISTINE SULFATE   Vincristine Sulfate         1   Hospira/Pfizer
#
# ...

# %%
len(df1.Brnd_Name.unique())
# Out:
# 75
